# %%
# %matplotlib notebook
# Import Pandas and then, since they are use frequently, import Series and Data Frame
# into the local namespace.
import pandas as pd
from pandas import Series, DataFrame

# Import matplotlib's pyplot to plot the data.
import matplotlib.pyplot as plt


# Load the Iris dataset which is in .csv format as a DataFrame. 
df = pd.read_csv(r"C:\Users\Stanzoman\Documents\projects\iris1.csv")
df.head()
# Out:
#    id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# Check how many species there are.
df["Species"].describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Species, dtype: object

# %%
# See the frequencies for each species.
df["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
# Summaryze the whole data frame (descriptive statistics on each column).
df.describe()
# Out:
#                id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Scatter plot of a pair of features.
df.plot(kind="scatter", x="SepalLengthCm", y="PetalLengthCm")
# Out:
# <img src="data:image/png;base64,...">

# %%
# Color/label dots according to Species 
ax = df[df.Species == "Iris-setosa"].plot(kind="scatter", x="SepalLengthCm", y="PetalLengthCm", color="red", label="Iris-setosa", title="SepalLenght vs. PetalLength")
df[df.Species == "Iris-virginica"].plot(kind="scatter", x="SepalLengthCm", y="PetalLengthCm", color="green", label="Iris-virginica", ax=ax)
df[df.Species == "Iris-versicolor"].plot(kind="scatter", x="SepalLengthCm", y="PetalLengthCm", color="blue", label="Iris-versicolor", ax=ax)
# Out:
# <img src="data:image/png;base64,...">

# %%
# Plot all combinations of two features scatter matrix
# First import panda's scatter_matrix into the namespace
from pandas.tools.plotting import scatter_matrix

# Plot by calling scatter_matrix
scatter_matrix(df.drop("id", axis=1), alpha=0.2, figsize=(10, 10), diagonal='kde')
# Out:
# <img src="data:image/png;base64,...">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x083B6290>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x08CF2530>]], dtype=object)

# %%
# Pandas's scatter_matrix cannot distinguish categories by color, but the seaborn 
# pairplot can.
# Import seaborn
import seaborn as sbn

# Make a pairplot
sbn.pairplot(df.drop("Id", axis=1), hue="Species", diag_kind="kde", size=3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-3e31d25189d0> in <module>()
#       2 # pairplot can.
#       3 # Import seaborn
# ----> 4 import seaborn as sbn
#       5
#       6 # Make a pairplot
#
# ImportError: No module named 'seaborn'
